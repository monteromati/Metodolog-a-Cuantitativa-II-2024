# %% [markdown]
# # **Introducción a Google Colab 👨🏽‍💻📈**
#
# Hola, ¡bienvenido a Google Colab! Google Colab es una plataforma gratuita que permite escribir y ejecutar código en Python en tu navegador con una configuración mínima. Es ampliamente utilizada para análisis de datos, aprendizaje automático y visualización de datos, entre otras aplicaciones.
#
# ## **Acceso a Google Colab**
#
# Para empezar a utilizar Google Colab, solo necesitas una cuenta de Google. Vamos paso a paso para acceder y configurar tu entorno de trabajo.
#
# ### **Paso 1: Acceso a Google Colab**
#
# 1.  **Visita el sitio oficial de Google Colab**:
#     -   Abre tu navegador web y dirígete a [Google Colab](https://colab.research.google.com/).
# 2.  **Inicia sesión con tu cuenta de Google**:
#     -   Si no has iniciado sesión, se te pedirá que lo hagas. Usa tu cuenta de Google para acceder.
# 3.  **Crea un nuevo cuaderno (notebook)**:
#     -   Haz clic en "File" (Archivo) y luego en "New Notebook" (Nuevo Cuaderno). Esto abrirá un nuevo cuaderno en blanco donde podrás escribir y ejecutar tu código Python.
#
# De ahora en adelante emplearemos Google Colab, que es la interfaz que nos permite utilizar Python de una forma amigable y sin necesidad de instalar nada en tu computadora.
#
# **Tip**
#
# ¿Sabías que? También puedes colaborar en Google Colab con tus colegas compartiendo el enlace de tu cuaderno, al igual que con Google Docs.
#
# ### **Explorando la interfaz de Google Colab**
#
# Como podrás haber notado, la interfaz de Google Colab está organizada en varios paneles, cada uno con un propósito:
#
# 1.  **Panel de Celdas de Código y Texto:** Aquí es donde escribes y ejecutas tu código Python y puedes añadir texto en formato Markdown para documentar tu trabajo.
# 2.  **Panel de Ejecución y Resultados:** Muestra los resultados de la ejecución de tu código, mensajes de error y advertencias. También puedes ver gráficos y otros tipos de salida.
# 3.  **Panel de Entorno (barra lateral):**
#     -   **Archivos:** Permite explorar los archivos y directorios de tu proyecto.
#     -   **Variables:** Muestra las variables y objetos de datos que has creado en tu sesión actual de Python.
# 4.  **Menú de Herramientas:** Accede a opciones adicionales como cambiar el entorno de ejecución, administrar bibliotecas instaladas y más.
#
# Para familiarizarte con Google Colab, te invito a que crees tu primer cuaderno y escribas el siguiente código para imprimir "¡Hola, mundo!":

# %%
print("¡Hola, mundo!")
# Out:
# ¡Hola, mundo!

# %% [markdown]
# Cuando ejecutas una celda de código, el resultado se mostrará justo debajo de la celda. Esto hace que sea muy fácil ver los resultados de tu trabajo y depurar cualquier problema que puedas encontrar.
#
# Creo que eso es todo por el momento... Ya estás listo para empezar a explorar el mundo de Python en Google Colab.

# %% [markdown]
# ## **Conceptos Básicos🔧**
#
# Clarifiquemos primero algunos términos que comúnmente utilizamos en Python. Te presento primero los objetos.
#
# **Tip**
#
# Siéntete libre de copiar y pegar el código de este taller en tu propio cuaderno. Para ejecutar una celda de código, simplemente haz clic en la celda y presiona Shift + Enter.

# %%
# Aquí asignamos un valor numérico a una variable "x"
x = 7
print(x)

# Aquí creamos una lista de números
num_var = [5, 3, 4]
print(num_var)

# Las listas pueden contener información de tipo texto o caracteres
char_var = ["verde", "amarillo", "verde"]
print(char_var)

# También utilizamos datos de tipo categórico usando pandas
import pandas as pd
factores = pd.Categorical(["femenino", "masculino", "masculino", "femenino"])
print(factores)

# Aunque los factores también pueden tener una lógica ordinal
factores_ord = pd.Categorical(["bajo", "medio", "alto", "alto"],
                              categories=["bajo", "medio", "alto"],
                              ordered=True)
print(factores_ord)

# Es posible almacenar valores lógicos que asume solo dos valores posibles
hola = [True, False, False, True]
print(hola)

# A veces tendremos datos perdidos representados por None en Python
vector_con_na = [1, 2, None, 4, 5]
print(vector_con_na)

# Python también es capaz de manejar información de fechas y tiempo (hora)
from datetime import datetime

fecha = datetime.strptime("2024-07-24", "%Y-%m-%d").date()
print(fecha)

fecha_hora = datetime.strptime("2024-07-24 12:34:56", "%Y-%m-%d %H:%M:%S")
print(fecha_hora)

# Oh mira, con el símbolo de almohadilla puedes anotar en el código para que no olvides lo que haces
# Out:
# 7
# [5, 3, 4]
# ['verde', 'amarillo', 'verde']
# ['femenino', 'masculino', 'masculino', 'femenino']
# Categories (2, object): ['femenino', 'masculino']
# ['bajo', 'medio', 'alto', 'alto']
# Categories (3, object): ['bajo' < 'medio' < 'alto']
# [True, False, False, True]
# [1, 2, None, 4, 5]
# 2024-07-24
# 2024-07-24 12:34:56

# %% [markdown]
# Como podrás haber intuido:
# *   Una lista es una secuencia de datos que puede contener diferentes tipos.
# *   El nombre creado a la variable es completamente a nuestra elección. Como ves en el ejemplo, puede llamarse char_var o hola.
#
# En general, trabajarás en Python usando un `DataFrame`, que significa cuadro de datos. Un `DataFrame` es un objeto que almacena un conjunto de series que, a su vez, pueden ser listas que almacenan información de tipo numérica, categórica, entre otros. Comúnmente, las series dentro de un `DataFrame` se conocen como columnas, las cuales almacenan atributos de la unidad de observación de nuestro conjunto de datos representados en las filas. Por ejemplo, las filas pueden ser estudiantes, escuelas, países, mientras que las columnas serán sus atributos (e.g., género).
#
# Aquí un ejemplo de cómo crear un `DataFrame` en Python:

# %%
import pandas as pd

# Creando un DataFrame
data = {
    "Nombre": ["Ana", "Luis", "Marta"],
    "Edad": [23, 45, 35],
    "Género": ["Femenino", "Masculino", "Femenino"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Nombre  Edad     Género
# 0    Ana    23   Femenino
# 1   Luis    45  Masculino
# 2  Marta    35   Femenino

# %% [markdown]
# En este ejemplo, el `DataFrame` `df` almacena tres columnas (Nombre, Edad, Género) con información sobre diferentes individuos.

# %% [markdown]
# ### **Ejercicio 1: Creando tu primer `DataFrame` 🕸️**
#
# En el cuaderno de Google Colab que generaste, crea una lista llamada `edad` que contenga cinco valores numéricos. También, crea una lista llamada `nombre` que contenga cinco nombres de personas de tipo cadena de texto.
#
# **Tip**
#
# Crea las listas como variables. Luego, utiliza la función `pd.DataFrame()` para almacenarlas en un DataFrame.
#
# Sobre este `DataFrame` podrás calcular diferentes estadísticos como un promedio o desviación estándar.

# %% [markdown]
# ### **Ejercicio 2: Explorar un `DataFrame` 🔍**
# Crea un objeto llamado `CarTab` empleando los datos `mtcars`, los cuales son datos de ejemplo de la revista Motor Trend US de 1974, donde cada fila es un auto y sus diferentes atributos (variables). Luego, sobre el objeto `CarTab`, emplea los comandos `type()`, `df.info()`, `df.head()`, y `df.describe()`. Termina calculando el promedio de la variable `hp` usando la función `mean()`.
#
# **Pista**
#
# Carga los datos de ejemplo `mtcars` importando el paquete `pydataset`. Asigna los datos de `mtcars` al objeto `CarTab` usando el signo igual `=`. Para usar los comandos, escribe el comando respectivo y, entre los paréntesis, el nombre del objeto `CarTab`. Para el comando `mean()`, especifica la columna usando `[]` del objeto.

# %% [markdown]
# Resumiendo, puedes manejar diferentes tipos de datos en Python:
#
# *   Numéricos: Números enteros y decimales.
# *   Cadenas de texto: Texto.
# *   Categóricos: Datos categóricos ordenados o no ordenados.
# *   Fechas: Información de tiempo en un formato de fecha, que también puede incluir hora.
# *   Lógicos: Valores de verdad (True o False).
# *   Datos perdidos: Información faltante (None o NaN) en un conjunto de datos.

# %% [markdown]
# ### **Ejercicio 3: Gráficos Básicos**
#
# En este ejercicio, vamos a crear gráficos básicos utilizando el objeto `CarTab`.
#
# 1.  **Crea un gráfico de dispersión**:
#     -   Muestra la relación entre las variables `horsepower` (caballos de fuerza) y `mpg` (millas por galón) del conjunto de datos `CarTab`. Para ello, importa la librería `matplotlib`, usa el comando `plt.scatter()`, indexando el DataFrame `CarTab` con las variables mencionadas anteriormente.
# 2.  **Dale color** 🎨:
#     -   Muestra la relación entre las mismas variables, pero esta vez colorea los puntos de azul. Utiliza el argumento `color=""` con el nombre del color que desees en inglés (e.g., "red"). Recuerda separar los argumentos con una coma `,`.
# 3.  **Crea un histograma**:
#     -   Muestra la distribución de la variable `qsec` (cuarto de milla en segundos) usando el comando `plt.hist()`.
#
# **Tip**
#
# Los gráficos son útiles para visualizar relaciones y distribuciones de datos. Elige el tipo de gráfico según tus preguntas de investigación y el tipo de análisis que necesites.

# %% [markdown]
# ### **Ejercicio 4: Transformación de Variables**
# En este ejercicio, aprenderás a crear nuevas variables a partir de las existentes en el objeto CarTab.
#
# **Tip**
#
# Transformar variables te permite crear nuevos indicadores y categorías para análisis más sofisticados.
#
# 1.   Crea una nueva variable nombrándola `rhpwt`.
#      *   Calcula una división entre `horsepower` (caballos de fuerza) y `weight` (peso en miles de libras) y almacénala en una nueva variable `rhpwt`.
#
# **Tip**
#
# Usa el operador de división `/` para calcularlo y guarda el resultado en `CarTab` asignándolo con el método assign.
#
# 1.   Crea una variable categórica `Rapido`:
#      *    Utiliza la función `np.where` para crear una nueva variable `Rapido` que tome el valor 1 si `qsec` es menor a 18, y 0 en caso contrario.
#
# **Tip**
# La función `np.where` tiene la estructura: `np.where(condición, valor_si_verdadero, valor_si_falso)`. Úsala para crear la variable `Rapido` basada en la condición lógica anterior. Usa el operador lógico `<`.

# %% [markdown]
# ### **Ejercicio 5: Indexación o Extracción de Datos**
#
# En este ejercicio, aprenderás a extraer subconjuntos de datos del objeto `CarTab`.
#
# 1.  **Extrae un subconjunto de datos**:
#     -   Extrae las columnas `qsec` y `Rapido` y almacénalas en un nuevo objeto llamado `Sub_CarTab`.
#
# **Tip**
#
# Usa la notación de corchetes `[]` para seleccionar columnas específicas de un DataFrame. La sintaxis es `nombre_data_frame[['nombre_columna1', 'nombre_columna2']]`.

# %% [markdown]
# ### **Ejercicio 6: Regresión lineal**
# En este ejercicio, estimarás un modelo de regresión lineal utilizando el objeto `CarTab`.
#
# 1.     Ajusta un modelo de regresión lineal:
#      *     Ajusta un modelo de regresión lineal que prediga `qsec` en función de `horsepower` y `weight` asignado a un objeto llamado `mod1`.
#
# **Tip**
# La función `sm.OLS()` de la librería `statsmodels` ajusta modelos de regresión lineal. La estructura es s`m.OLS(y, X).fit()`, donde `y` es la variable dependiente y `X` son los predictores. Usa `mod1.summary()` para obtener las estimaciones del modelo ajustado.
#
# Al final de este documento encontrarás las soluciones a los ejercicios.

# %% [markdown]
# # **Análisis Descriptivo** 📊
#
# ¿Cómo se ve un flujo de trabajo inicial de análisis de datos en Python utilizando Google Colab? Un flujo de trabajo típico de análisis de datos en Google Colab comienza con la configuración del entorno de trabajo. En Google Colab, puedes cargar archivos desde tu Google Drive o desde tu sistema de archivos local, y organizar tus datos y scripts de manera eficiente.
#
# ## **¿Cómo cargar archivos en Google Colab?**
#
# 1.  **Carga archivos desde tu sistema de archivos local**:
#     -   Usa el método `files.upload()` de la librería `google.colab` para subir archivos directamente desde tu computadora.

# %%
from google.colab import files

# Cargar archivos desde tu computadora local
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0fc5dadb-3f62-49b9-8661-e367c25a5639" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0fc5dadb-3f62-49b9-8661-e367c25a5639">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 2.     **Carga archivos desde Google Drive:**
#      *     Usa la librería `google.colab.drive` para montar tu Google Drive y acceder a los archivos almacenados allí.

# %%
from google.colab import drive

# Montar Google Drive
drive.mount('/content/drive')

# Establecer el directorio de trabajo a una carpeta específica en Google Drive
import os
os.chdir('/content/drive/My Drive/Teaching/Metodología Cuantitativa II 2024/Sesión 1')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Puedes verificar el directorio de trabajo actual utilizando la función `os.getcwd()`, que te mostrará la ruta del directorio de trabajo establecido.

# %%
print(os.getcwd())
# Out:
# /content/drive/My Drive/Teaching/Metodología Cuantitativa II 2024/Sesión 1

# %% [markdown]
# Organiza tus archivos en subcarpetas dentro de tu directorio de trabajo, por ejemplo, data para datos brutos, scripts para tus scripts de Python, y outputs para resultados como gráficos y tablas. Te recomiendo el protocolo IPO que puedes ver [aquí](https://lisa-coes.com/ipo-repro/) para organizar tus carpetas. Con esto, tendrás un flujo de trabajo ordenado, y tu futuro yo te lo agradecerá.

# %% [markdown]
# ## **Instalación de Librerías**
#
# Para llevar a cabo análisis de datos en Python, a menudo necesitamos librerías adicionales que no vienen incluidos en la instalación base. Estos paquetes contienen funciones y datasets adicionales que facilitan diversas tareas.
#
# 1.  **Instalación de Paquetes**:
#     -   Usa `!pip install` para instalar los paquetes necesarios.

# %%
# !pip install pandas openpyxl pyjanitor matplotlib seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.0/202.0 kB 2.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# 2. **Carga de Paquetes:**
#    - Después de instalar los paquetes, usa `import` para cargarlos en tu sesión de Python.

# %%
import pandas as pd
import janitor
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Importar Datos**
# Para importar datos en Python desde un archivo Excel, usaremos el paquete `pandas`.
#
# 1. **Importa los datos:**
# Usa la función `pd.read_excel()` para leer los datos de un archivo Excel y almacenarlos en un DataFrame. Asegúrate tener descargado el archivo Excel `Base-Personal-Academico-2021_SIES.xlsx` en tu directorio de trabajo.

# %%
personal_2021 = pd.read_excel("Base-Personal-Academico-2021_SIES.xlsx")

# %% [markdown]
# 2. **Visualiza los datos**
#    - Usa la función `head()` para ver las primeras filas del DataFrame.

# %%
print(personal_2021.head())
# Out:
#    Código institución            Nombre institución  Total Mujeres  \
# 0                   1  UNIVERSIDAD GABRIELA MISTRAL            108
# 1                   2      UNIVERSIDAD FINIS TERRAE            551
# 2                   3    UNIVERSIDAD DIEGO PORTALES            894
# 3                   4  UNIVERSIDAD CENTRAL DE CHILE            457
# 4                   7       UNIVERSIDAD BOLIVARIANA            149
#
#    Total Hombres  Total General  Promedio Edad Mujeres  Promedio Edad Hombres  \
# 0          138.0            246              46.185185              46.101449
# 1          671.0           1222              43.695100              45.825633
# 2         1111.0           2005              44.055928              45.372637
# 3          600.0           1057              44.986871              47.541667
# 4          184.0            333              43.248322              49.103261
#
#    Promedio Edad por institución  Menos de 35 mujeres  Entre 35 y 44 mujeres  \
# ...

# %% [markdown]
# ## **Limpieza de Datos**
# Los nombres de las columnas en la base de datos pueden necesitar limpieza para ser más manejables.
#
# 1. **Limpia los nombres de las columnas:**
#    - Usa la función `clean_names()` del paquete `pyjanitor` para estandarizar los nombres de las columnas.

# %%
# Install pyjanitor
# !pip install pyjanitor

# Import necessary libraries
import pandas as pd
import janitor

# Load the data
personal_2021 = pd.read_excel("Base-Personal-Academico-2021_SIES.xlsx")

# Use pyjanitor to clean column names
personal_2021 = personal_2021.clean_names()

# Display the first few rows to verify the changes
print(personal_2021.head())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...
#    codigo_institucion            nombre_institucion  total_mujeres  \
# 0                   1  UNIVERSIDAD GABRIELA MISTRAL            108
# 1                   2      UNIVERSIDAD FINIS TERRAE            551
# 2                   3    UNIVERSIDAD DIEGO PORTALES            894
# 3                   4  UNIVERSIDAD CENTRAL DE CHILE            457
# 4                   7       UNIVERSIDAD BOLIVARIANA            149
#
#    total_hombres  total_general  promedio_edad_mujeres  promedio_edad_hombres  \
# 0          138.0            246              46.185185              46.101449
# ...

# %% [markdown]
# 2. **Exploremos los datos:**
#      - Usa diversas funciones para obtener una visión general de los datos.

# %%
print(type(personal_2021))  # Muestra la clase de objeto de personal_2021
print(personal_2021.head())  # Muestra los primeros 6 casos en la base de datos
print(personal_2021.columns)  # Lista los nombres de las variables en la base de datos
print(personal_2021.shape)  # Muestra el número de variables y casos
print(personal_2021.describe())  # Entrega estadísticos descriptivos para cada variable
print(personal_2021.info())  # Muestra la estructura interna de la base de datos
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
#    codigo_institucion            nombre_institucion  total_mujeres  \
# 0                   1  UNIVERSIDAD GABRIELA MISTRAL            108
# 1                   2      UNIVERSIDAD FINIS TERRAE            551
# 2                   3    UNIVERSIDAD DIEGO PORTALES            894
# 3                   4  UNIVERSIDAD CENTRAL DE CHILE            457
# 4                   7       UNIVERSIDAD BOLIVARIANA            149
#
#    total_hombres  total_general  promedio_edad_mujeres  promedio_edad_hombres  \
# 0          138.0            246              46.185185              46.101449
# ...

# %% [markdown]
# 3. **Generación de nuevas variables:**
#    - Crear una nueva variable `tipo_ies`:
# Primero, genera una nueva variable `tipo_ies` que inicialmente sea igual a `codigo_institucion`.

# %%
personal_2021['tipo_ies'] = personal_2021['codigo_institucion']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# 2. **Asignar valores a `tipo_ies` según `codigo_institucion`**
#    - En este ejercicio, asignarás valores a la nueva columna `tipo_ies` basada en los valores de `codigo_institucion`.

# %%
# Asignar valores a `tipo_ies` según `codigo_institucion`
personal_2021.loc[personal_2021['codigo_institucion'].isin([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 895, 896]), 'tipo_ies'] = 1
personal_2021.loc[personal_2021['codigo_institucion'].isin([3, 34, 69, 86, 87, 88, 89, 90, 91, 92, 93, 94]), 'tipo_ies'] = 2
personal_2021.loc[personal_2021['codigo_institucion'].isin([1, 2, 4, 7, 9, 10, 11, 13, 17, 19, 20, 22, 23, 26, 31, 38, 39, 42, 45, 46, 48, 50, 54, 68, 651]), 'tipo_ies'] = 3
personal_2021.loc[personal_2021['codigo_institucion'].isin([99, 100, 101, 103, 104, 106, 108, 111, 113, 116, 117, 120, 123, 129, 132, 137, 138, 139, 143, 144, 152, 155, 162, 165, 170, 171, 176, 193, 676, 693, 714, 743, 754, 767]), 'tipo_ies'] = 4
personal_2021.loc[personal_2021['codigo_institucion'].isin([214, 218, 229, 236, 241, 257, 260, 273, 280, 305, 312, 319, 328, 331, 367, 374, 382, 390, 398, 426, 427, 430, 435, 450, 456, 492, 498, 534, 536, 591, 629, 633, 691, 701, 730, 258]), 'tipo_ies'] = 5
personal_2021.loc[personal_2021['codigo_institucion'].isin([902, 906, 908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920]), 'tipo_ies'] = 6
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### **Visualización y Etiquetado de Datos**
# 1. **Visualiza los valores generados:**

# %%
print(personal_2021['tipo_ies'])
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 129    6
# 130    6
# 131    6
# 132    6
# 133    6
# Name: tipo_ies, Length: 134, dtype: int64
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# 2. **Asigna etiquetas a los valores generados:**
#    - Usa la función `pd.Categorical()` para asignar etiquetas a los valores de `tipo_ies`.

# %%
personal_2021['tipo_ies_n'] = pd.Categorical(personal_2021['tipo_ies'],
                                             categories=[1, 2, 3, 4, 5, 6],
                                             ordered=True)
personal_2021['tipo_ies_n'] = personal_2021['tipo_ies_n'].cat.rename_categories(["U. ESTATAL", "U. PRIVADA CRUCH", "U. PRIVADA", "IP", "CFT PRIVADO", "CFT ESTATAL"])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### **Selección de Subconjuntos de Datos**
# Para trabajar con subconjuntos específicos de datos, puedes usar la función `query()` o la notación de corchetes `[]`.
#
# 1. **Selecciona un subconjunto de datos:**
#    - Filtra las filas del `DataFrame` según la nueva variable categórica `tipo_ies_n`.

# %%
personal_2021_uestatal = personal_2021[personal_2021['tipo_ies_n'] == "U. ESTATAL"]
print(personal_2021_uestatal.head())
# Out:
#     codigo_institucion                nombre_institucion  total_mujeres  \
# 27                  70              UNIVERSIDAD DE CHILE           1509
# 28                  71  UNIVERSIDAD DE SANTIAGO DE CHILE           1118
# 29                  72         UNIVERSIDAD DE VALPARAÍSO            749
# 30                  73        UNIVERSIDAD DE ANTOFAGASTA            239
# 31                  74          UNIVERSIDAD DE LA SERENA            256
#
#     total_hombres  total_general  promedio_edad_mujeres  \
# 27         2423.0           3932              49.025845
# 28         2025.0           3143              44.668157
# 29          999.0           1748              45.034713
# 30          321.0            560              47.154812
# 31          412.0            668              44.988281
#
#     promedio_edad_hombres  promedio_edad_por_institucion  menos_de_35_mujeres  \
# 27              52.965745                      51.453713                155.0
# ...

# %% [markdown]
# ## **Soluciones de los Ejercicios**
#
# ### **Ejercicio 1**

# %%
import pandas as pd

edad = [40, 5, 16, 28, 32]
nombre = ["Daniel", "Mariela", "Miguel", "Pablo", "Javiera"]
misdatos = pd.DataFrame({
    "nombre": nombre,
    "edad": edad
})
print(misdatos)
# Out:
#     nombre  edad
# 0   Daniel    40
# 1  Mariela     5
# 2   Miguel    16
# 3    Pablo    28
# 4  Javiera    32
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### **Ejercicio 2**

# %%
# !pip install pydataset

from pydataset import data
import pandas as pd

CarTab = data('mtcars')

print(type(CarTab))
print(CarTab)
print(CarTab.info())
print(CarTab.head())
print(CarTab.describe())
print(CarTab['hp'].mean())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 50.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939416 sha256=6977abe8e2b838f283bc9fe5295d6d9a904021e4b0ca8e47847d4dc5c4c3c067
#   Stored in directory: /root/.cache/pip/wheels/2b/83/5c/073c3755e8b7704e4677557b2055e61026c1a2342149214c13
# Successfully built pydataset
# ...
# initiated datasets repo at: /root/.pydataset/
# <class 'pandas.core.frame.DataFrame'>
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# ...

# %% [markdown]
# ### Ejercicio 3

# %%
import matplotlib.pyplot as plt

plt.scatter(CarTab['hp'], CarTab['mpg'])
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.title('Scatter plot of Horsepower vs MPG')
plt.show()

plt.scatter(CarTab['hp'], CarTab['mpg'], color='blue')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.title('Scatter plot of Horsepower vs MPG (Blue)')
plt.show()

plt.hist(CarTab['qsec'])
plt.xlabel('Quarter Mile Time (seconds)')
plt.ylabel('Frequency')
plt.title('Histogram of Quarter Mile Time')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### **Ejercicio 4**

# %%
# Create new variable 'rhpwt' (ratio of horsepower to weight)
CarTab['rhpwt'] = CarTab['hp'] / CarTab['wt']
print(CarTab['rhpwt'])

# Create new variable 'Rapido' (1 if qsec < 18, else 0)
CarTab['Rapido'] = (CarTab['qsec'] < 18).astype(int)
print(CarTab)
# Out:
# Mazda RX4              41.984733
# Mazda RX4 Wag          38.260870
# Datsun 710             40.086207
# Hornet 4 Drive         34.214619
# Hornet Sportabout      50.872093
# Valiant                30.346821
# Duster 360             68.627451
# Merc 240D              19.435737
# Merc 230               30.158730
# Merc 280               35.755814
# Merc 280C              35.755814
# Merc 450SE             44.226044
# Merc 450SL             48.257373
# Merc 450SLC            47.619048
# Cadillac Fleetwood     39.047619
# Lincoln Continental    39.638643
# Chrysler Imperial      43.030870
# Fiat 128               30.000000
# Honda Civic            32.198142
# Toyota Corolla         35.422343
# Toyota Corona          39.350913
# Dodge Challenger       42.613636
# AMC Javelin            43.668122
# Camaro Z28             63.802083
# Pontiac Firebird       45.513654
# Fiat X1-9              34.108527
# Porsche 914-2          42.523364
# Lotus Europa           74.686054
# ...

# %% [markdown]
# ### **Ejercicio 5**

# %%
Sub_CarTab = CarTab[['qsec', 'Rapido']]
print(Sub_CarTab)
# Out:
#                       qsec  Rapido
# Mazda RX4            16.46       1
# Mazda RX4 Wag        17.02       1
# Datsun 710           18.61       0
# Hornet 4 Drive       19.44       0
# Hornet Sportabout    17.02       1
# Valiant              20.22       0
# Duster 360           15.84       1
# Merc 240D            20.00       0
# Merc 230             22.90       0
# Merc 280             18.30       0
# Merc 280C            18.90       0
# Merc 450SE           17.40       1
# Merc 450SL           17.60       1
# Merc 450SLC          18.00       0
# Cadillac Fleetwood   17.98       1
# Lincoln Continental  17.82       1
# Chrysler Imperial    17.42       1
# Fiat 128             19.47       0
# Honda Civic          18.52       0
# Toyota Corolla       19.90       0
# Toyota Corona        20.01       0
# Dodge Challenger     16.87       1
# AMC Javelin          17.30       1
# Camaro Z28           15.41       1
# Pontiac Firebird     17.05       1
# Fiat X1-9            18.90       0
# ...

# %% [markdown]
# **Ejercicio 6**

# %%
import statsmodels.api as sm

y = CarTab['qsec']
X = CarTab[['hp', 'wt']]
X = sm.add_constant(X)

mod1 = sm.OLS(y, X).fit()
print(mod1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   qsec   R-squared:                       0.652
# Model:                            OLS   Adj. R-squared:                  0.628
# Method:                 Least Squares   F-statistic:                     27.17
# Date:                Wed, 07 Aug 2024   Prob (F-statistic):           2.25e-07
# Time:                        01:24:35   Log-Likelihood:                -46.584
# No. Observations:                  32   AIC:                             99.17
# Df Residuals:                      29   BIC:                             103.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.8256      0.672     28.020      0.000      17.451      20.200
# ...

# %% [markdown]
# Para citar este archivo de Google Colab, por favor, considera este formato: Montero, M., Ortega, L. & Rodríguez, P. (2024). Metodología Cuantitativa II 2024 [Repositorio]. GitHub. https://github.com/monteromati/Metodologia-Cuantitativa-II-2024
